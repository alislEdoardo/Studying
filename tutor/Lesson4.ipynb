# %% [markdown]
# # Autoencoders

# %% [markdown]
# *Tutors*:
# -- Federico Milanesio: federico.milanesio@unito.it
# -- Davide Pirovano: davide.pirovano@unito.it

# %% [markdown]
# <div>
# <img src="https://imgs.xkcd.com/comics/ai_hiring_algorithm.png" width="550"/>
# </div>

# %%
import torch
from torch import nn
from torch import optim
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import torchvision.transforms as transforms
import torchvision

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print(device)
# Out:
# cuda:0

# %% [markdown]
# # Setting up an autoencoder

# %% [markdown]
# We will use MNIST as our dataset. Note that we do not normalize our output given that they are already normalized in the range $[0,1]$, making additional normalization less critical. In the case of autoencoders, the primary goal is to **learn a representation (encoding) of the input data** that can accurately reconstruct the original input. The effectiveness of an autoencoder relies more on the architecture of the model and the optimization process rather than the preprocessing of input data. Still, this needs to be evaluated on a case-by-case basis

# %%
transform = transforms.Compose([
    transforms.ToTensor(),                              # <-- we dont normalize here, can you guess why based on the rest of the notebook?
])

train_dataset = torchvision.datasets.MNIST(root='./data', train=True, download=False, transform=transform)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, download=False, transform=transform)

batch_size = 128
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# We now define our model. A few notes:
#
#
# 1.   We use linear layers for simplicity, but you can use any type of layer you want
# 2.   Encoder and decoder **do not share weights** in this case.
# 3. At the end we use a sigmoid forces the output to the range $[0, 1]$, interpreted as pixel intensity of a grey scale image. **figata sta cosa**
#
# Sharing weights between the encoder and decoder can reduce the total number of model parameters, which may lead to **simpler models** and reduced risk of overfitting, especially when training data is limited. But tied weights restrict the flexibility of the model, potentially limiting its ability to capture complex relationships between input and output. Whether to share weights between encoder and decoder is a choice that is based on **Task Complexity** and the application of you network

# %%
width = 28
enc_dim = 14
# encoder layers
#osservazione: se metti un solo layer non riesce a ricostruire bene!!
encoder = nn.Sequential(
  nn.Linear(width*width, enc_dim*enc_dim),
  nn.ReLU(),
  nn.Linear(enc_dim*enc_dim, 10),


)

# decoder layers
decoder = nn.Sequential(
  nn.Linear(10, enc_dim*enc_dim),
  nn.ReLU(),
  nn.Linear(enc_dim*enc_dim, width*width),

)


model = nn.Sequential(
    nn.Flatten(1, 3), #ti flattena dalla dimensione 1 alla dimensione 3!!
    encoder,
    decoder,
    nn.Sigmoid(),                       # output pixel values in range [0, 1] for grayscale images!!
    nn.Unflatten(1, (1, width, width)) #we want to unflatten the 2nd dimension from that dimension to a tensor (1,28,28)
)

model = model.to(device)

# %% [markdown]
# We will use **MSE**, a popular choice for training autoencoders, but other losses can be tried as well, such as Binary Cross Entropy and L1

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(),
                       lr=1e-2,
                       weight_decay=1e-6)

# %%
# %%time

num_epochs = 5
for epoch in range(num_epochs):

    loss_epoch = 0.0

    for x, _ in train_loader:

        x = x.to(device)

        x_pred = model(x)
        loss = criterion(x_pred, x)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_epoch += loss.item()

    print(f"Epoch {epoch + 1}, Loss: {loss_epoch / len(train_loader):.5f}") #for printing to 5th decimal!!
# Out:
# Epoch 1, Loss: 0.02756
# Epoch 2, Loss: 0.01919
# Epoch 3, Loss: 0.01822
# Epoch 4, Loss: 0.01777
# Epoch 5, Loss: 0.01744
# CPU times: total: 42.3 s
# Wall time: 38.3 s

# %%
#test_loader.dataset[0] #mi prende il primo batch

# %% [markdown]
# When training autoencoders, often it best to see the result of reconstruction instead of focusing only on the numerical loss of the model

# %%
with torch.no_grad():
    for images, _ in test_loader:  # sto iterando sul primo batch perché in test loader ci sono tutti i batches
      model = model.cpu()
      reconstructed_images = model(images.cpu())
      break

def plot_images(images, title):
    plt.figure(figsize=(8, 4))
    for i in range(8):
        plt.subplot(2, 4, i + 1)
        plt.imshow(images[i].squeeze().numpy(), cmap='gray')
        plt.axis('off')
    plt.suptitle(title, y=1.05)
    plt.tight_layout()

# plot original and reconstructed images
plot_images(images, title="Original Images")
plot_images(reconstructed_images, title="Reconstructed Images")

plt.show() #qui vediamo che ricostruisce male

# %% [markdown]
# **Exercise 1**: Define the encoder and decoder modules for our autoencoder. Can we improve its performance by **optimizing hyperparameters** and adjusting the model architecture? Additionally, can we include a **visualization of the train and test loss** over the training process to detect signs of overfitting?

# %%
...
# Out:
# Ellipsis

# %% [markdown]
# # Exploring the representations

# %% [markdown]
# Now that we have a trained autoencoder, we can **look inside the model** and explore what it has learned. To do this, we will use PCA.
#
# PCA finds the set of $m$ variables as linear combinations of the original variables that explains the most variance. It can be shown that the principal components are eigenvectors of the data's covariance matrix $\frac{1}{n}X^TX$. We will find the first two and plot them to see how well the autoencoder **clusters** similar examples.

# %%
enumerate(test_loader)

# %%
from sklearn.decomposition import PCA

model = model.to(device)

latents = []
labels = []

with torch.no_grad():
    for i, (x, y) in enumerate(test_loader):
        x = x.to(device)
        z = model[0:2](x) #sto usando il modello fino al secondo layer in modo
        latents.append(z.cpu())
        labels.append(y)

latents, labels = torch.cat(latents), torch.cat(labels)

# %%
pca = PCA(n_components=2, random_state=42)
latents_2d = pca.fit_transform(latents)

plt.figure(figsize=(8, 6))
scatter = plt.scatter(latents_2d[:, 0], latents_2d[:, 1], c=labels, cmap="tab10", alpha=0.7)
plt.colorbar(scatter, label="digit")
plt.title("pca of latent space")
plt.show()

# %% [markdown]
# Now we try to **move through the latent space**?
#
# We'll pick two input images $x_1$, $x_2$, encode them into the latent space $z_1$, $z_2$, and linearly interpolate between them.
#
# $z_{\text{new}}=\alpha z_1 + (1-\alpha)z_2$, $\;\;\;\alpha \in [0,1]$
#
# Then, we'll decode each intermediate point back into an image.
#
# This reveals how the model interprets smooth transitions in the underlying data distribution. Ideally, we should see a gradual morphing from one digit to another.

# %%
steps = 10

(x1, _), (x2, _) = test_dataset[0], test_dataset[1]  # <-- we select two samples from the dataset

z1 = model[0:2](x1.unsqueeze(0).to(device))
z2 = model[0:2](x2.unsqueeze(0).to(device))

interpolated = torch.stack([
        z1 * (1 - alpha) + z2 * alpha
        for alpha in torch.linspace(0, 1, steps)
    ]).squeeze()

with torch.no_grad():
  decoded = model[2:](interpolated).cpu()

fig, axes = plt.subplots(1, steps, figsize=(steps, 1.5))
for i, ax in enumerate(axes):
    ax.imshow(decoded[i][0], cmap="gray")
    ax.axis("off")
plt.suptitle("Latent Space Interpolation")
plt.show()

# %% [markdown]
# We can compare the result with blending images by averaging pixels directly (not via the latent space).

# %%
interpolated = torch.stack([
        x1 * (1 - alpha) + x2 * alpha
        for alpha in torch.linspace(0, 1, steps)
    ])

fig, axes = plt.subplots(1, steps, figsize=(steps, 1.5))
for i, ax in enumerate(axes):
    ax.imshow(interpolated[i][0], cmap="gray")
    ax.axis("off")
plt.suptitle("Original Space Interpolation")
plt.show()

# %% [markdown]
# # Denoising autoencoders

# %% [markdown]
# Let's see how well our autoencoder performs over noisy images, where we added Gaussian noise.

# %%
def add_noise(inputs, noise_factor=0.4):
    noisy = inputs + noise_factor * torch.randn_like(inputs)
    noisy = torch.clamp(noisy, 0., 1.)    # <-- clamps all elements 0 < x < 1
    return noisy

# %%
for x, _ in train_loader:
  x = x[:8].to(device)                 # <-- we select 8 points
  noisy_x = add_noise(x)
  recon = model(noisy_x).detach()
  break

fig, axs = plt.subplots(3, 8, figsize=(8 * 1.5, 4))
for i in range(8):
  axs[0, i].imshow(x[i][0].cpu(), cmap="gray")
  axs[1, i].imshow(noisy_x[i][0].cpu(), cmap="gray")
  axs[2, i].imshow(recon[i][0].cpu(), cmap="gray")
  for row in axs:
    row[i].axis('off')

fig.text(0.1, 0.8, "Original", va='center', ha='right', fontsize=12, rotation='vertical')
fig.text(0.1, 0.5, "Noisy", va='center', ha='right', fontsize=12, rotation='vertical')
fig.text(0.1, 0.2, "Autoencoder", va='center', ha='right', fontsize=12, rotation='vertical')


plt.show()

# %% [markdown]
# A **denoising autoencoder** is trained not just to reconstruct its input, but to remove noise from it.
#
# During training, we corrupt the input image (e.g., by adding Gaussian noise), but we still ask the model to reconstruct the original, clean version. This encourages the autoencoder to learn more robust and meaningful representations.

# %% [markdown]
# **Exercise 2**: Train a denoising autoencoder on the noisy images. Can it remove noise while preserving the underlying structure?

# %%
denoising_model = model

# %%
model[0]
# Out:
# Flatten(start_dim=1, end_dim=3)

# %%
# %%time
optimizer = optim.Adam(model.parameters(),
                       lr=1e-2,
                       weight_decay=1e-6)
num_epochs = 5

for epoch in range(num_epochs):

    loss_epoch = 0.0

    for x_train, _ in train_loader:

        x_train = x_train.to(device)

        noisy_x = add_noise(x_train)       # <-- we train on noisy data
        x_pred = denoising_model(noisy_x)

        loss = criterion(x_pred, x_train)  # <-- the loss is computed on the noiseless image

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
# Out:
# CPU times: user 35.8 s, sys: 103 ms, total: 35.9 s
# Wall time: 36.5 s

# %% [markdown]
# Let's visualize the performance of the denoising model compared to the original autoencoder.

# %%
for x, _ in train_loader:
  x = x[:8].to(device)                 # <-- we select 8 points
  noisy_x = add_noise(x, noise_factor=0.8)
  recon = model(noisy_x).detach()
  denoising_recon = denoising_model(noisy_x).detach()
  break

fig, axs = plt.subplots(4, 8, figsize=(8 * 1, 8))
for i in range(8):
  axs[0, i].imshow(x[i][0].cpu(), cmap="gray")
  axs[1, i].imshow(noisy_x[i][0].cpu(), cmap="gray")
  axs[2, i].imshow(recon[i][0].cpu(), cmap="gray")
  axs[3, i].imshow(denoising_recon[i][0].cpu(), cmap="gray")
  for row in axs:
    row[i].axis('off')

fig.text(0.1, 0.8, "Original", va='center', ha='right', fontsize=12, rotation='vertical')
fig.text(0.1, 0.6, "Noisy", va='center', ha='right', fontsize=12, rotation='vertical')
fig.text(0.1, 0.4, "Autoencoder", va='center', ha='right', fontsize=12, rotation='vertical')
fig.text(0.1, 0.2, "Denoising", va='center', ha='right', fontsize=12, rotation='vertical')

plt.show()

# %% [markdown]
# FACCIAMO PARAMETER SHARING

# %%
#generiamo i dati su una sfera
R = 10

# %%
class Autoencoder(nn.Module):
  def __init__(self, enc_dim):
    super().__init__()
    self.encoder = nn.Sequential(
        nn.Flatten(1,3),
        nn.Linear(in_features = width*width, out_features=100),
        nn.ReLU(),
        nn.Linear(in_features=100, out_features= enc_dim*enc_dim)
      )
    self.decoder = nn.Sequential(
        nn.Linear(in_features=enc_dim*enc_dim, out_features= 100),
        nn.ReLU(),
        nn.Linear(100, width*width),
        nn.Sigmoid(),
        nn.Unflatten(1, (1, width, width)) # Restore image shape
        )
    # Parameter sharing (tied weights)
    # self.decoder[2] (Linear 100->784) ties with self.encoder[1] (Linear 784->100)
    self.decoder[2].weight = nn.Parameter(self.encoder[1].weight.t())
    # self.decoder[0] (Linear enc_dim^2->100) ties with self.encoder[3] (Linear 100->enc_dim^2)
    self.decoder[0].weight = nn.Parameter(self.encoder[3].weight.t())

  def forward(self, input):
    encoded = self.encoder(input)
    decoded = self.decoder(encoded)
    return decoded

# %%
in_dim = 5
model_2 = Autoencoder(in_dim)
model_2 = model_2.to(device)

# %%
# %%time
# Re-instantiate model and optimizer to apply changes
model_2 = Autoencoder(in_dim).to(device)
optimizer = optim.Adam(model_2.parameters(), lr=1e-2, weight_decay=1e-6)

num_epochs = 5
losses_train = []

for epoch in range(num_epochs):
    loss_epoch = 0.0
    for x_train, _ in train_loader:
        x_train = x_train.to(device)
        noisy_x = add_noise(x_train)

        x_pred = model_2(noisy_x)
        loss = criterion(x_pred, x_train)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_epoch += loss.item()

    avg_loss = loss_epoch / len(train_loader)
    losses_train.append(avg_loss)
    print(f"Epoch {epoch + 1}, Loss: {avg_loss:.5f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:626: UserWarning: Using a target size (torch.Size([128, 1, 28, 28])) that is different to the input size (torch.Size([128, 784])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <timed exec> in <module>
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     624         Runs the forward pass.
#     625         """
# --> 626         return F.mse_loss(input, target, reduction=self.reduction)
#     627
#     628
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/functional.py in mse_loss(input, target, size_average, reduce, reduction, weight)
#    3929         reduction = _Reduction.legacy_get_string(size_average, reduce)
#    3930
# -> 3931     expanded_input, expanded_target = torch.broadcast_tensors(input, target)
#    3932
#    3933     if weight is not None:
#
# /usr/local/lib/python3.12/dist-packages/torch/functional.py in broadcast_tensors(*tensors)
#      75     if has_torch_function(tensors):
#      76         return handle_torch_function(broadcast_tensors, tensors, *tensors)
# ---> 77     return _VF.broadcast_tensors(tensors)  # type: ignore[attr-defined]
#      78
#      79
#
# RuntimeError: The size of tensor a (784) must match the size of tensor b (28) at non-singleton dimension 3

# %% [markdown]
# ```markdown
# ### Measuring Execution Time
#
# You can use `%%time` to see how long a single run takes, or `%%timeit` for an average of multiple runs.
# ```

# %%
# %%time
# This will measure the time for a single execution
import time
time.sleep(1) # Simulating a task
# Out:
# CPU times: user 1.28 ms, sys: 9 µs, total: 1.29 ms
# Wall time: 1 s

# %% [markdown]
# *© 2024. This work is openly licensed via [CC BY-NC-SA 4.0 DEED](https://creativecommons.org/licenses/by-nc-sa/4.0/)*

# %% [markdown]
# *Comics used in the notebooks are from [xkcd.com](https://xkcd.com), and are licensed under the Creative Commons Attribution-NonCommercial 2.5 license.*
#
# *Details and usage notes can be found at [xkcd.com/license.html](https://xkcd.com/license.html).*
